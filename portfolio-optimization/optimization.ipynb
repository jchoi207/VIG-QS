# %% [markdown]
# **See notes on the types of optimization problems**

# %%
import opt_functions as opt

# %%
## Choose universe of stocks
universe = ["AAPL", "GOOG", "MSFT", "VOO"]

## Choose minimum and maximum weights for each stock
min_max_weights = {
    "AAPL": [0.1, 0.5],
    "GOOG": [0.1, 0.5],
    "MSFT": [0.1, 0.5],
    "VOO":  [0.3, 0.5]
}

opt_dict, start_date, end_date = opt.optimize(
    universe, start_date="2015-01-01", end_date="2018-01-01", min_max_weights=None, short_selling=False, min_return=1.5)
opt.portfolio_performance(opt_dict, start_date, end_date, principal=200)
# Out:
# ___________Summary___________
# AAPL: 0.0%
# GOOG: 15.476%
# MSFT: 18.69%
# VOO: 65.834%
#
# Expected monthly portfolio returns: 1.5%
# Portfolio st.dev: 12.4
#
# Simple Rate of Return: 58.95%
